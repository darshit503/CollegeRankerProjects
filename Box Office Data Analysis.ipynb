# %% [markdown]
# # <center>Box Office Data Analytics</h2>

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 1: Data Loading and Exploration

# %%
data=pd.read_csv(r"C:\Users\Asus\PycharmProjects\Darshit\box_office.csv")

# %%
data.head(10)
# Out:
#     id    budget                               homepage    imdb_id  \
# 2    3   3300000      http://sonyclassics.com/whiplash/  tt2582802
# 6    7  14000000     http://www.thepossessionmovie.com/  tt0431021
# 12  13  15000000          http://www.dreamworks.com/ab/  tt0169547
# 15  16    500000  http://skinningmovie.com/synopsis.htm  tt1129437
# 22  23         0    http://www.magnetreleasing.com/vhs/  tt2105044
# 23  24         0            http://insightthemovie.com/  tt1687277
# 24  25         0    http://www.blacksheep-themovie.com/  tt0779982
# 32  33  90000000   http://www.thelastwitchhunter.movie/  tt1618442
# 35  36  30000000            http://www.safethefilm.com/  tt1656190
# 38  39         0             http://www.watchfinal.com/  tt2710368
#
#    original_language         original_title  \
# 2                 en               Whiplash
# 6                 en         The Possession
# 12                en        American Beauty
# 15                sr                Šišanje
# 22                en                  V/H/S
# 23                en                InSight
# 24                en            Black Sheep
# 32                en  The Last Witch Hunter
# 35                en                   Safe
# 38                en     Final: The Rapture
#
#                                              overview  popularity  \
# 2   Under the direction of a ruthless instructor, ...   64.299990
# 6   A young girl buys an antique box at a yard sal...    7.286477
# 12  Lester Burnham, a depressed suburban father in...   20.726578
# 15  Novica is a mathematics champion in a Belgrade...    1.018477
# 22  When a group of misfits is hired by an unknown...    7.820787
# 23  Kaitlyn, an ER nurse who is tending to a young...    1.323333
# 24  A genetic engineering experiment gone horribly...    7.434577
# 32  The modern world holds many secrets, but by fa...   13.412445
# 35  After a former elite agent rescues a 12-year-o...    8.234382
# 38  A gritty, international tale of four separate ...    0.329260
#
#                          poster_path release_date  ...  departments_Art  \
# 2   /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg     10/10/14  ...                5
# 6   /4QjzFuaZmB4btGnLwAgdp23BzIU.jpg      8/30/12  ...                4
# 12  /or1MP8BZIAjqWYxPdPX724ydKar.jpg      9/15/99  ...               11
# 15  /88l8VBanH0lS5Wvzu2qgkGcsfQi.jpg      10/6/10  ...                1
# 22  /yo49x6Jhr1ecCjy1ByFqwAbtARJ.jpg      7/28/12  ...                0
# 23  /7oJksA5Bi7UdrVZhudIg6GaHpRz.jpg       9/2/11  ...                0
# 24  /8YoL8WSHv7UKTq7iziI7SrRmdql.jpg       9/9/06  ...                3
# 32  /xw1GFKzxjgfm3dQoK1swFcHmfaC.jpg     10/21/15  ...                7
# 35  /eoiqqDHohBCDwFWQOvczUeNoixK.jpg      4/16/12  ...                3
# 38  /4VYYvaHtnrQcxQGLaDFRLxCEpyw.jpg      9/13/13  ...                0
#
#    departments_Crew departments_Writing departments_Costume & Make-Up  \
# 2                 9                   1                             5
# 6                11                   4                            12
# 12               23                   3                            11
# 15                5                   4                             3
# 22                0                   6                             0
# 23                0                   2                             0
# 24                0                   1                             1
# 32                7                   4                            13
# 35                0                   1                             2
# 38                0                   1                             0
#
#    departments_Camera  departments_Directing departments_Editing  \
# 2                   4                      3                   6
# 6                  11                      4                   9
# 12                  7                      5                   8
# 15                  3                      1                   2
# 22                  0                     10                   0
# 23                  1                      1                   1
# 24                  1                      1                   1
# 32                 11                      4                  10
# 35                  1                      2                   3
# 38                  0                      1                   0
#
#     departments_Visual Effects  departments_Lighting departments_Actors
# 2                            3                     1                  0
# 6                            2                     4                  0
# 12                           8                     3                  0
# 15                           0                     0                  0
# 22                           0                     0                  0
# 23                           0                     0                  0
# 24                           0                     0                  0
# 32                          21                     0                  0
# 35                           0                     0                  0
# 38                           0                     0                  0
#
# [10 rows x 203 columns]

# %%
data.isna().sum()
# Out:
# id                               0
# budget                           0
# homepage                      2054
# imdb_id                          0
# original_language                0
#                               ...
# departments_Directing            0
# departments_Editing              0
# departments_Visual Effects       0
# departments_Lighting             0
# departments_Actors               0
# Length: 203, dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.describe()
# Out:
#                 id        budget  popularity     runtime       revenue  \
# count   798.000000  7.980000e+02  798.000000  798.000000  7.980000e+02
# mean   1482.815789  4.097408e+07   12.496881  109.349624  1.374351e+08
# std     854.604091  5.270069e+07   20.078253   19.048754  2.217756e+08
# min       3.000000  0.000000e+00    0.158651   40.000000  4.000000e+00
# 25%     768.750000  5.000000e+06    6.713486   95.000000  7.678020e+06
# 50%    1459.500000  2.000000e+07    9.562828  106.000000  5.197698e+07
# 75%    2236.500000  5.600000e+07   13.265730  121.000000  1.570693e+08
# max    3000.000000  3.800000e+08  294.337037  180.000000  1.519558e+09
#
#        has_collection  num_genres  genre_Drama  genre_Comedy  genre_Thriller  \
# count      798.000000  798.000000   798.000000    798.000000      798.000000
# mean         0.263158    2.571429     0.462406      0.313283        0.281955
# std          0.440624    1.055207     0.498897      0.464119        0.450234
# min          0.000000    1.000000     0.000000      0.000000        0.000000
# 25%          0.000000    2.000000     0.000000      0.000000        0.000000
# 50%          0.000000    3.000000     0.000000      0.000000        0.000000
# 75%          1.000000    3.000000     1.000000      1.000000        1.000000
# max          1.000000    6.000000     1.000000      1.000000        1.000000
#
#        ...  departments_Art  departments_Crew  departments_Writing  \
# count  ...       798.000000        798.000000           798.000000
# mean   ...         3.978697          3.692982             2.458647
# std    ...         5.084559          7.037788             1.754770
# min    ...         0.000000          0.000000             0.000000
# 25%    ...         0.000000          0.000000             1.000000
# 50%    ...         3.000000          1.000000             2.000000
# 75%    ...         5.000000          4.000000             3.000000
# max    ...        28.000000         88.000000            14.000000
#
#        departments_Costume & Make-Up  departments_Camera  \
# count                     798.000000           798.00000
# mean                        3.340852             2.54386
# std                         4.799008             3.31378
# min                         0.000000             0.00000
# 25%                         0.000000             1.00000
# 50%                         1.000000             1.00000
# 75%                         5.000000             3.00000
# max                        33.000000            23.00000
#
#        departments_Directing  departments_Editing  departments_Visual Effects  \
# count             798.000000           798.000000                  798.000000
# mean                1.810777             2.065163                    2.397243
# std                 1.318923             2.169311                    5.463128
# min                 0.000000             0.000000                    0.000000
# 25%                 1.000000             1.000000                    0.000000
# 50%                 1.000000             1.000000                    0.000000
# 75%                 2.000000             3.000000                    2.000000
# max                17.000000            14.000000                   52.000000
#
#        departments_Lighting  departments_Actors
# count            798.000000               798.0
# mean               0.685464                 0.0
# std                1.507011                 0.0
# min                0.000000                 0.0
# 25%                0.000000                 0.0
# 50%                0.000000                 0.0
# 75%                1.000000                 0.0
# max               12.000000                 0.0
#
# [8 rows x 190 columns]

# %% [markdown]
# ## Task 2: Visualizing the Target Distribution

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
sns.distplot(data['revenue'],hist=False,color='blue')
plt.title("Revenue")
plt.show()
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Task 3: Relationship between Film Revenue and Budget

# %%
plt.figure(figsize=(20,10))
sns.jointplot(y=data['revenue'],x=data['budget'],kind='scatter',color='green')
plt.title("Revenue vs Budget")
plt.show()

# %% [markdown]
# ## Task 4: Distribution of Languages in Film

# %%
data.loc[data['original_language'].isin(data['original_language'].value_counts().head().index)]
# Out:
#         id    budget                                           homepage  \
# 2        3   3300000                  http://sonyclassics.com/whiplash/
# 6        7  14000000                 http://www.thepossessionmovie.com/
# 12      13  15000000                      http://www.dreamworks.com/ab/
# 22      23         0                http://www.magnetreleasing.com/vhs/
# 23      24         0                        http://insightthemovie.com/
# ...    ...       ...                                                ...
# 2984  2985  80000000        http://www.sonypictures.com/homevideo/swat/
# 2985  2986  37665000  http://www.sonypictures.com/homevideo/freedoml...
# 2993  2994  60000000               http://www.theterminal-themovie.com/
# 2998  2999  42000000                     http://www.alongcamepolly.com/
# 2999  3000  35000000                   http://www.abductionthefilm.com/
#
#         imdb_id original_language    original_title  \
# 2     tt2582802                en          Whiplash
# 6     tt0431021                en    The Possession
# 12    tt0169547                en   American Beauty
# 22    tt2105044                en             V/H/S
# 23    tt1687277                en           InSight
# ...         ...               ...               ...
# 2984  tt0257076                en          S.W.A.T.
# 2985  tt0349467                en       Freedomland
# 2993  tt0362227                en      The Terminal
# 2998  tt0343135                en  Along Came Polly
# 2999  tt1600195                en         Abduction
#
#                                                overview  popularity  \
# 2     Under the direction of a ruthless instructor, ...   64.299990
# 6     A young girl buys an antique box at a yard sal...    7.286477
# 12    Lester Burnham, a depressed suburban father in...   20.726578
# 22    When a group of misfits is hired by an unknown...    7.820787
# 23    Kaitlyn, an ER nurse who is tending to a young...    1.323333
# ...                                                 ...         ...
# 2984  Hondo Harrelson recruits Jim Street to join an...   13.334952
# 2985  A black police detective must solve a strange ...    5.388535
# 2993  Viktor Navorski is a man without a country; hi...   14.092373
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542
# 2999  A young man sets out to uncover the truth abou...   10.512109
#
#                            poster_path release_date  ...  departments_Art  \
# 2     /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg     10/10/14  ...                5
# 6     /4QjzFuaZmB4btGnLwAgdp23BzIU.jpg      8/30/12  ...                4
# 12    /or1MP8BZIAjqWYxPdPX724ydKar.jpg      9/15/99  ...               11
# 22    /yo49x6Jhr1ecCjy1ByFqwAbtARJ.jpg      7/28/12  ...                0
# 23    /7oJksA5Bi7UdrVZhudIg6GaHpRz.jpg       9/2/11  ...                0
# ...                                ...          ...  ...              ...
# 2984  /AgwobKKS20WRaQCHj5ut2R4KyHa.jpg       8/8/03  ...               10
# 2985  /uoYZmNzUjTEvW0vktaVfMRJZA8s.jpg      2/17/06  ...                4
# 2993  /f4Dup6awDfDqAHKgWqNJ2HFw1qN.jpg      6/17/04  ...                6
# 2998  /nIY4kvJTTnxoBR0wycrXng5MOYs.jpg      1/16/04  ...               12
# 2999  /cUT6NQP5LAJpmUoStGtXmvNt4zA.jpg      9/22/11  ...                8
#
#      departments_Crew departments_Writing departments_Costume & Make-Up  \
# 2                   9                   1                             5
# 6                  11                   4                            12
# 12                 23                   3                            11
# 22                  0                   6                             0
# 23                  0                   2                             0
# ...               ...                 ...                           ...
# 2984               22                   6                             9
# 2985                0                   1                             1
# 2993                3                   3                            15
# 2998               10                   1                            14
# 2999                4                   1                             7
#
#      departments_Camera  departments_Directing departments_Editing  \
# 2                     4                      3                   6
# 6                    11                      4                   9
# 12                    7                      5                   8
# 22                    0                     10                   0
# 23                    1                      1                   1
# ...                 ...                    ...                 ...
# 2984                  7                      3                   4
# 2985                  1                      1                   1
# 2993                  6                      3                   5
# 2998                  9                      4                   9
# 2999                  3                      2                   2
#
#       departments_Visual Effects  departments_Lighting departments_Actors
# 2                              3                     1                  0
# 6                              2                     4                  0
# 12                             8                     3                  0
# 22                             0                     0                  0
# 23                             0                     0                  0
# ...                          ...                   ...                ...
# 2984                           4                     6                  0
# 2985                           0                     0                  0
# 2993                           4                     3                  0
# 2998                           0                     3                  0
# 2999                           5                     0                  0
#
# [770 rows x 203 columns]

# %%
data['original_language'].unique()
# Out:
# array(['en', 'sr', 'es', 'zh', 'ko', 'ja', 'de', 'cn', 'hi', 'fr', 'da',
#        'ru', 'no', 'nb', 'fa', 'sv', 'nl', 'id', 'hu', 'ml'], dtype=object)

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.boxplot(x=data['original_language'],y=data['budget'])
plt.title("Mean Budget per Language")
plt.show()
